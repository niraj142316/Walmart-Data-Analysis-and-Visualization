# %% [markdown]
# # Walmart Data Analysing Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec as gs
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
store1_df = pd.read_csv('store1.csv')
sampleSubmission_df = pd.read_csv('sampleSubmission.csv')
feature_df = pd.read_csv('features.csv')

# %% [markdown]
# Analysing each imported data frames.
#
# Viewing the data in train_df
#
# Here, we can see that the dataframe has weekly sales data in accordance with store, department and date.

# %%
train_df.tail()
# Out:
#        Store  Dept        Date  Weekly_Sales  IsHoliday
# 37553      4    79  2011-11-18      50313.63      False
# 37554      4    79  2011-11-25      56756.50       True
# 37555      4    79  2011-12-02      49346.99      False
# 37556      4    79  2011-12-09      51086.67      False
# 37557      4    79  2011-12-16      54260.97      False

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37558 entries, 0 to 37557
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         37558 non-null  int64
#  1   Dept          37558 non-null  int64
#  2   Date          37558 non-null  object
#  3   Weekly_Sales  37558 non-null  float64
#  4   IsHoliday     37558 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# Describe the data in train_df, that is mean count etc of the numerical columns in the data frame.

# %%
train_df.describe()
# Out:
#               Store          Dept   Weekly_Sales
# count  37558.000000  37558.000000   37558.000000
# mean       2.395974     40.961553   19661.018258
# std        1.101295     28.397314   27831.183177
# min        1.000000      1.000000   -1098.000000
# 25%        1.000000     18.000000    2784.537500
# 50%        2.000000     35.000000    8460.870000
# 75%        3.000000     59.000000   25042.330000
# max        4.000000     99.000000  385051.040000

# %% [markdown]
# This shows the how many null values in each column in the train_df data frame, we can see that there are no any null values in this data frame

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %% [markdown]
# Viewing the data of test_df  dataframe

# %%
test_df.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
test_df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'IsHoliday'], dtype='object')

# %% [markdown]
# we can see the info of test_df dataframe

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Store      115064 non-null  int64
#  1   Dept       115064 non-null  int64
#  2   Date       115064 non-null  object
#  3   IsHoliday  115064 non-null  bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB

# %% [markdown]
# Now describe the data frame test_df for mean count value and other related informaton also.

# %%
test_df.describe()
# Out:
#                Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %% [markdown]
# checking for null values in the dataframe.

# %%
test_df.isnull().sum()
# Out:
# Store        0
# Dept         0
# Date         0
# IsHoliday    0
# dtype: int64

# %%
store1_df.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
store1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
store1_df.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
store1_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
feature_df.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %%
feature_df.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
feature_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %% [markdown]
# **Create a new data frame by merging(inner) feature data frame to store1 date frame on Store for analysis purpose.**

# %%
feaSt_mer = feature_df.merge(store1_df, how='inner', on = 'Store')
feaSt_mer.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
# 2        NaN        NaN        NaN  211.289143         8.106      False    A
# 3        NaN        NaN        NaN  211.319643         8.106      False    A
# 4        NaN        NaN        NaN  211.350143         8.106      False    A
#
#      Size
# 0  151315
# 1  151315
# 2  151315
# 3  151315
# 4  151315

# %% [markdown]
# gathering information regarding columns of above new merged data frame

# %%
feaSt_mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %% [markdown]
# **Converting date to datetime object**

# %%
from datetime import datetime

feaSt_mer['Date'] = pd.to_datetime(feaSt_mer['Date'])
train_df['Date'] = pd.to_datetime(train_df['Date'])
test_df['Date'] = pd.to_datetime(test_df['Date'])

# Extract week and year from the date and make them into new columns.

feaSt_mer['Week'] = feaSt_mer.Date.dt.isocalendar().week

feaSt_mer['Year'] = feaSt_mer.Date.dt.isocalendar().year

# %%
feaSt_mer.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45 2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45 2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45 2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45 2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45 2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday Type  \
# 8185       3.00    2449.97    3169.69  NaN           NaN      False    B
# 8186     582.74    5797.47    1514.93  NaN           NaN      False    B
# 8187      85.72     744.84    2150.36  NaN           NaN      False    B
# 8188     204.19     363.00    1059.46  NaN           NaN      False    B
# 8189       2.06      10.88    1864.57  NaN           NaN      False    B
#
#         Size  Week  Year
# 8185  118221    26  2013
# 8186  118221    27  2013
# 8187  118221    28  2013
# 8188  118221    29  2013
# 8189  118221    30  2013

# %% [markdown]
# **Creating again a new data frame by merging(inner) the train_df and the new merged data frame feaSt_mer on Store, Date and isholiday columns and sorting the values by Store, Department and Date**

# %%
train_df_1 = train_df.merge(feaSt_mer, how='inner', on=['Store', 'Date', 'IsHoliday']).sort_values(by=['Store', 'Dept', 'Date']).reset_index(drop=True)

# %%
train_df_1.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     1 2010-02-12      46039.49       True        38.51       2.548
# 2      1     1 2010-02-19      41595.55      False        39.93       2.514
# 3      1     1 2010-02-26      19403.54      False        46.63       2.561
# 4      1     1 2010-03-05      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size  Week  Year
# 0         8.106    A  151315     5  2010
# 1         8.106    A  151315     6  2010
# 2         8.106    A  151315     7  2010
# 3         8.106    A  151315     8  2010
# 4         8.106    A  151315     9  2010

# %% [markdown]
# # ----------------------------------                                             VISUALIZATIONS                                                                                                          -----------------------------------

# %% [markdown]
# Defining a function scatter to plot the scatter plot with the data of the column specified as the function parameter in x axis and weekly sales as the y values.

# %% [markdown]
# **1) Scatter Plot**

# %%
def scatter(column):
    #plot the figure with respect to column
    plt.figure()
    #plot the scatter figure of the data specified by column and weekly sales
    plt.scatter(train_df[column], train_df['Weekly_Sales'])
    #give y level as weekly sales
    plt.ylabel('Weekly_Sales')
    #give the x level as given column
    plt.xlabel(column)

# %%
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to Store
scatter('Store')
#plot a scatter plot using the scatter function a scatter plot of weekly sales with respect to Department
scatter('Dept')

# %% [markdown]
# We can see scatter plots of weekly sales with respect to stores and department, we can see that departments between 60 and 80 are performing better.

# %% [markdown]
# **2) 3 line plots for weekly sales for exact year**

# %%
#Filtering out mean weekly sales for the year 2010

#weekly_sales_2010 = train_df_1[train_df_1['Year']==2010]['Weekly_Sales'].groupby(train_df_1['Week']).mean()

#Plot a line plot with week on x axis and sales for that particular week of the filtered year in y axis

sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Week'>

# %%
#filtering out mean weekly sales for the year 2011
weekly_sales_2011= train_df_1[train_df_1['Year']==2011]['Weekly_Sales'].groupby(train_df_1['Week']).mean()

#plot the lineplot with week on x axis and sales for that particular week of the year

sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color='red')
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Week'>

# %%
# filtering out mean weekly sales for the year 2012

weekly_sales_2012 = train_df_1[train_df_1['Year']==2012]['Weekly_Sales'].groupby(train_df_1['Week']).mean()

# plot the lineplot of week on x axis and the mean of weekly sales for that particular year

sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color='green')
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Week'>

# %% [markdown]
# **3) Combined line plots for each year (2010,2011,2012)**
#
# **Plotting the weekly sales for years 2010,2011,2012 on a single plot to compare the sales values with respect to week on each of these specified year for comparing the weekly sales in each year.**

# %%
# plotting the figure
plt.figure(figsize =(20, 10))

#plottine the three lineplot for weekly sales for each year
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values, color='red')
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values, color='green')
plt.grid()

#plotting labels and legends
plt.xticks(np.arange(1, 60, step=1))
plt.title('Average Weekly Sales Per Year')
plt.xlabel('Week', fontsize =16)
plt.ylabel('Sales', fontsize=16)
plt.legend(['2010', '2011', '2012'], loc='best', fontsize=16)
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **We can see the above line plot on 51th week 2010 weekly sales is highest.**
#
#
# Line plots between week and weekly sales is a good way to compare sales for each year.

# %% [markdown]
# **4) Histogram / Normal distribution**

# %%
f, ax = plt.subplots(figsize=(8,6))

# Creating distribution for weekly sales in the dataframe train_df
sns.histplot(train_df['Weekly_Sales'], color='g')
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Count'>

# %%
#Skewness is a measure of symmetry, or more precisely, the lack of symmetry. A distribution, or data set, is symmetric if it looks the same to the left and right of the center point.
print('Skewness: ', train_df['Weekly_Sales'].skew())#skewness

#Kurtosis is a measure of whether the data are heavy-tailed or light-tailed relative to a normal distribution. That is, data sets with high kurtosis tend to have heavy tails, or outliers. Data sets with low kurtosis tend to have light tails, or lack of outliers
print('Kurtosis: ', train_df['Weekly_Sales'].kurt())#kurtosis
# Out:
# Skewness:  2.671737935317216
# Kurtosis:  10.100101762761787

# %% [markdown]
# The above code is to determine the skewness and kurtosis of the normal distribution

# %% [markdown]
# **5) Box Plot**

# %%
#concatinating the type and column from store_df together to find the relation between stores falling under each type and size.
store_concat = pd.concat([store1_df['Type'], store1_df['Size']], axis=1)
f,ax=plt.subplots(figsize=(8, 6))

# Draw the box plot to show the relation between type and size of the store
fig = sns.boxplot(x= 'Type', y= 'Size', data=store_concat)

# %% [markdown]
# From the above box plots we can see that Type A plots are the largest, ie has the largest size

# %% [markdown]
# **6) Bar Chart on data frame**
#
#
# **Grouping the train_df by store and computing the mean of weekly_sales for each store.**

# %%
weekly_sales_store=train_df['Weekly_Sales'].groupby(train_df['Store']).mean()
#visualizing the data
weekly_sales_store.head()
# Out:
# Store
# 1    21710.543621
# 2    26898.070031
# 3     6373.033983
# 4    22768.226221
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **Converting the data of weekly_sales_store into pandas dataframe**

# %%
weekly_sales_store_df = pd.DataFrame(weekly_sales_store)
weekly_sales_store_df.tail()
# Out:
#        Weekly_Sales
# Store
# 1      21710.543621
# 2      26898.070031
# 3       6373.033983
# 4      22768.226221

# %% [markdown]
# **Sorting the dataframe with respect to weekly sales in decending order**

# %%
weekly_sales_store_df.sort_values("Weekly_Sales", ascending=False).style.bar(align='left', width=200, color= '#FFD200')
# Out:
# <style type="text/css">
# #T_56dec_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FFD200 200.0%, transparent 200.0%);
# }
# #T_56dec_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FFD200 159.8%, transparent 159.8%);
# }
# #T_56dec_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#FFD200 149.5%, transparent 149.5%);
# }
# #T_56dec_row3_col0 {
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_56dec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56dec_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_56dec_row0_col0" class="data row0 col0" >26898.070031</td>
#     </tr>
#     <tr>
#       <th id="T_56dec_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_56dec_row1_col0" class="data row1 col0" >22768.226221</td>
#     </tr>
#     <tr>
#       <th id="T_56dec_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_56dec_row2_col0" class="data row2 col0" >21710.543621</td>
#     </tr>
#     <tr>
#       <th id="T_56dec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_56dec_row3_col0" class="data row3 col0" >6373.033983</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **In the above dataframe the highest weekly sales is for store 2**
#
# **Now sort the dataframe with respect to weekly sales and in ascending order and then plotting the bar graph on the dataframe itself to know the idea about data**

# %%
weekly_sales_store_df.sort_values("Weekly_Sales").style(align='left', width =200, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7704/1491894224.py in <module>
# ----> 1 weekly_sales_store_df.sort_values("Weekly_Sales").style(align='left', width =200, color='red')
#
# TypeError: 'Styler' object is not callable

# %% [markdown]
# Here in the above dataframe the lowest mean weekly sales is for store 3

# %% [markdown]
# **7) Bar graph for mean weekly sales for each store.**
#
#
#
# **Plotting a bar graph with store number as x values and mean weekly sales for that store as the y values.**

# %%
#plotting the figure
plt.figure(figsize=(25,12))

#Creating a barplot with stores in x axis and mean weekly sales for each store as y values.
sns.barplot(weekly_sales_store.index, weekly_sales_store.values, palette='dark')

#create the grid
plt.grid()

#give the title and labels of figure
plt.title('Average Weekly Sales Per Store', fontsize=20)
plt.xlabel('Store Number', fontsize=16)
plt.ylabel('Weekly Sales per store', fontsize=16)
plt.show()
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Grouping the train_df by Department and computing the mean of weekly sales for each department**

# %%
weekly_sales_dept=train_df['Weekly_Sales'].groupby(train_df['Dept']).mean()

# %%
weekly_sales_dept.head()
# Out:
# Dept
# 1    24399.966206
# 2    55624.025997
# 3    13787.208462
# 4    36902.351923
# 5    28044.257448
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# **Converting weekly_sales_dept to pandas dataframe**

# %%
weekly_sales_dept_df=pd.DataFrame(weekly_sales_dept)
weekly_sales_dept_df
# Out:
#       Weekly_Sales
# Dept
# 1     24399.966206
# 2     55624.025997
# 3     13787.208462
# 4     36902.351923
# 5     28044.257448
# ...            ...
# 95    93368.780769
# 96    23350.462770
# 97    25592.564061
# 98    11489.236304
# 99      396.367595
#
# [78 rows x 1 columns]

# %% [markdown]
# **Sorting the dataframe with respect to weekly sales in decreasing order**

# %%
weekly_sales_dept_df.sort_values("Weekly_Sales", ascending=False).style.bar(align='left', width=98, color ='#d65f5f')
# Out:
# <style type="text/css">
# #T_c8d7e_row0_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
# }
# #T_c8d7e_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 89.2%, transparent 89.2%);
# }
# #T_c8d7e_row2_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 84.5%, transparent 84.5%);
# }
# #T_c8d7e_row3_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 67.9%, transparent 67.9%);
# }
# #T_c8d7e_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 58.3%, transparent 58.3%);
# }
# #T_c8d7e_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 57.8%, transparent 57.8%);
# }
# #T_c8d7e_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 55.8%, transparent 55.8%);
# }
# #T_c8d7e_row7_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 53.6%, transparent 53.6%);
# }
# #T_c8d7e_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 53.1%, transparent 53.1%);
# }
# #T_c8d7e_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 46.2%, transparent 46.2%);
# }
# #T_c8d7e_row10_col0, #T_c8d7e_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 39.6%, transparent 39.6%);
# }
# #T_c8d7e_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 35.3%, transparent 35.3%);
# }
# #T_c8d7e_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 30.1%, transparent 30.1%);
# }
# #T_c8d7e_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.3%, transparent 28.3%);
# }
# #T_c8d7e_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 28.2%, transparent 28.2%);
# }
# #T_c8d7e_row16_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 26.8%, transparent 26.8%);
# }
# #T_c8d7e_row17_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.8%, transparent 25.8%);
# }
# #T_c8d7e_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 25.3%, transparent 25.3%);
# }
# #T_c8d7e_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 24.5%, transparent 24.5%);
# }
# #T_c8d7e_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 23.3%, transparent 23.3%);
# }
# #T_c8d7e_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.9%, transparent 22.9%);
# }
# #T_c8d7e_row22_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.6%, transparent 22.6%);
# }
# #T_c8d7e_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 22.3%, transparent 22.3%);
# }
# #T_c8d7e_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 20.1%, transparent 20.1%);
# }
# #T_c8d7e_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
# }
# #T_c8d7e_row26_col0, #T_c8d7e_row27_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 19.2%, transparent 19.2%);
# }
# #T_c8d7e_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.7%, transparent 16.7%);
# }
# #T_c8d7e_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 16.6%, transparent 16.6%);
# }
# #T_c8d7e_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 14.1%, transparent 14.1%);
# }
# #T_c8d7e_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 13.2%, transparent 13.2%);
# }
# #T_c8d7e_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.6%, transparent 12.6%);
# }
# #T_c8d7e_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 12.4%, transparent 12.4%);
# }
# #T_c8d7e_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 11.0%, transparent 11.0%);
# }
# #T_c8d7e_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 10.8%, transparent 10.8%);
# }
# #T_c8d7e_row36_col0, #T_c8d7e_row37_col0, #T_c8d7e_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.9%, transparent 9.9%);
# }
# #T_c8d7e_row39_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
# }
# #T_c8d7e_row40_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 9.1%, transparent 9.1%);
# }
# #T_c8d7e_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.9%, transparent 8.9%);
# }
# #T_c8d7e_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
# }
# #T_c8d7e_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 8.2%, transparent 8.2%);
# }
# #T_c8d7e_row44_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 7.3%, transparent 7.3%);
# }
# #T_c8d7e_row45_col0, #T_c8d7e_row46_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.9%, transparent 6.9%);
# }
# #T_c8d7e_row47_col0, #T_c8d7e_row48_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 6.7%, transparent 6.7%);
# }
# #T_c8d7e_row49_col0, #T_c8d7e_row50_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
# }
# #T_c8d7e_row51_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 5.2%, transparent 5.2%);
# }
# #T_c8d7e_row52_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
# }
# #T_c8d7e_row53_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.7%, transparent 4.7%);
# }
# #T_c8d7e_row54_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.2%, transparent 4.2%);
# }
# #T_c8d7e_row55_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
# }
# #T_c8d7e_row56_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.9%, transparent 3.9%);
# }
# #T_c8d7e_row57_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
# }
# #T_c8d7e_row58_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.9%, transparent 2.9%);
# }
# #T_c8d7e_row59_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.7%, transparent 2.7%);
# }
# #T_c8d7e_row60_col0, #T_c8d7e_row61_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.6%, transparent 2.6%);
# }
# #T_c8d7e_row62_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
# }
# #T_c8d7e_row63_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
# }
# #T_c8d7e_row64_col0, #T_c8d7e_row65_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
# }
# #T_c8d7e_row66_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
# }
# #T_c8d7e_row67_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 1.0%, transparent 1.0%);
# }
# #T_c8d7e_row68_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
# }
# #T_c8d7e_row69_col0, #T_c8d7e_row70_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
# }
# #T_c8d7e_row71_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
# }
# #T_c8d7e_row72_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(

# %% [markdown]
# here, in above dataframe department number 92 has the maximum average weekly sales

# %% [markdown]
# **Sorting the dataframe with respect to weekly sales in ascending order and then plotting the bar graph to know the idea about the data.**

# %%
weekly_sales_dept_df.sort_values("Weekly_Sales").style.bar(align='left', width=100, color ='red')
# Out:
# <style type="text/css">
# #T_8f833_row0_col0 {
#   width: 10em;
#   height: 80%;
# }
# #T_8f833_row1_col0, #T_8f833_row2_col0, #T_8f833_row3_col0, #T_8f833_row4_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 0.0%, transparent 0.0%);
# }
# #T_8f833_row5_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 0.1%, transparent 0.1%);
# }
# #T_8f833_row6_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 0.4%, transparent 0.4%);
# }
# #T_8f833_row7_col0, #T_8f833_row8_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 0.5%, transparent 0.5%);
# }
# #T_8f833_row9_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 0.6%, transparent 0.6%);
# }
# #T_8f833_row10_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 1.0%, transparent 1.0%);
# }
# #T_8f833_row11_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 1.3%, transparent 1.3%);
# }
# #T_8f833_row12_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 1.5%, transparent 1.5%);
# }
# #T_8f833_row13_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 1.6%, transparent 1.6%);
# }
# #T_8f833_row14_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 1.9%, transparent 1.9%);
# }
# #T_8f833_row15_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 2.2%, transparent 2.2%);
# }
# #T_8f833_row16_col0, #T_8f833_row17_col0, #T_8f833_row18_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 2.7%, transparent 2.7%);
# }
# #T_8f833_row19_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 3.0%, transparent 3.0%);
# }
# #T_8f833_row20_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 3.6%, transparent 3.6%);
# }
# #T_8f833_row21_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 4.0%, transparent 4.0%);
# }
# #T_8f833_row22_col0, #T_8f833_row23_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 4.2%, transparent 4.2%);
# }
# #T_8f833_row24_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 4.8%, transparent 4.8%);
# }
# #T_8f833_row25_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 5.0%, transparent 5.0%);
# }
# #T_8f833_row26_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 5.3%, transparent 5.3%);
# }
# #T_8f833_row27_col0, #T_8f833_row28_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 5.6%, transparent 5.6%);
# }
# #T_8f833_row29_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 6.8%, transparent 6.8%);
# }
# #T_8f833_row30_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 6.9%, transparent 6.9%);
# }
# #T_8f833_row31_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 7.0%, transparent 7.0%);
# }
# #T_8f833_row32_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 7.1%, transparent 7.1%);
# }
# #T_8f833_row33_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 7.5%, transparent 7.5%);
# }
# #T_8f833_row34_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 8.3%, transparent 8.3%);
# }
# #T_8f833_row35_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 8.8%, transparent 8.8%);
# }
# #T_8f833_row36_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 9.1%, transparent 9.1%);
# }
# #T_8f833_row37_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 9.3%, transparent 9.3%);
# }
# #T_8f833_row38_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 9.8%, transparent 9.8%);
# }
# #T_8f833_row39_col0, #T_8f833_row40_col0, #T_8f833_row41_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 10.1%, transparent 10.1%);
# }
# #T_8f833_row42_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 11.1%, transparent 11.1%);
# }
# #T_8f833_row43_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 11.2%, transparent 11.2%);
# }
# #T_8f833_row44_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 12.6%, transparent 12.6%);
# }
# #T_8f833_row45_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 12.8%, transparent 12.8%);
# }
# #T_8f833_row46_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 13.5%, transparent 13.5%);
# }
# #T_8f833_row47_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 14.4%, transparent 14.4%);
# }
# #T_8f833_row48_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 16.9%, transparent 16.9%);
# }
# #T_8f833_row49_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 17.0%, transparent 17.0%);
# }
# #T_8f833_row50_col0, #T_8f833_row51_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 19.6%, transparent 19.6%);
# }
# #T_8f833_row52_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 20.2%, transparent 20.2%);
# }
# #T_8f833_row53_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 20.5%, transparent 20.5%);
# }
# #T_8f833_row54_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 22.8%, transparent 22.8%);
# }
# #T_8f833_row55_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 23.1%, transparent 23.1%);
# }
# #T_8f833_row56_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 23.4%, transparent 23.4%);
# }
# #T_8f833_row57_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 23.8%, transparent 23.8%);
# }
# #T_8f833_row58_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 25.0%, transparent 25.0%);
# }
# #T_8f833_row59_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 25.8%, transparent 25.8%);
# }
# #T_8f833_row60_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 26.3%, transparent 26.3%);
# }
# #T_8f833_row61_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 27.3%, transparent 27.3%);
# }
# #T_8f833_row62_col0, #T_8f833_row63_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 28.8%, transparent 28.8%);
# }
# #T_8f833_row64_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 30.7%, transparent 30.7%);
# }
# #T_8f833_row65_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 36.0%, transparent 36.0%);
# }
# #T_8f833_row66_col0, #T_8f833_row67_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 40.4%, transparent 40.4%);
# }
# #T_8f833_row68_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 47.2%, transparent 47.2%);
# }
# #T_8f833_row69_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 54.2%, transparent 54.2%);
# }
# #T_8f833_row70_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 54.7%, transparent 54.7%);
# }
# #T_8f833_row71_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 56.9%, transparent 56.9%);
# }
# #T_8f833_row72_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 59.0%, transparent 59.0%);
# }
# #T_8f833_row73_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 59.5%, transparent 59.5%);
# }
# #T_8f833_row74_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 69.3%, transparent 69.3%);
# }
# #T_8f833_row75_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 86.2%, transparent 86.2%);
# }
# #T_8f833_row76_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 91.0%, transparent 91.0%);
# }
# #T_8f833_row77_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,red 100.

# %% [markdown]
# here, Deparrtment 47 has the minimum average weekly sales.

# %% [markdown]
# ***9) Bar graph on average weekly sales per department***
#
#
#
# **Plotting a bar graph with Department number as x values and mean weekly sales for that store as the y values.**

# %%
#plot the figure
plt.figure(figsize=(20,10))

#Creating a barplot with department in x axis and mean weekly sales for each department as y values.
sns.barplot(weekly_sales_dept.index, weekly_sales_dept.values)

#plotting grid
plt.grid()

#give ttitle and lebels of the dataframe
plt.title('Average Weekly Sales Per Department', fontsize = 25)
plt.xlabel('Department Number', fontsize=16)
plt.ylabel('Sales per DE]epr,wmr')
# Out:
# C:\Users\niraj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Sales per DE]epr,wmr')

# %% [markdown]
# We can see that weekly sales is highest for department 92

# %% [markdown]
# **10) Series of lineplot for mean sales with respect to department**
#
#
#
# **Creating lineplots of mean weekly sales for each departments.**

# %%
#Creating a dataframe grouped by grouping the train_df on department and date.
grouped=train_df.groupby(['Dept', 'Date']).mean().reset_index()

#filtering out the department, date and weekly sales from the new dataframe gruoped.
data=grouped[['Dept', 'Date', 'Weekly_Sales']]

#Finding the unique values in the department.
dept = train_df['Dept'].unique()
#Sort the unique values in the column of department.
dept.sort()
#Divide the department into 4 batches.
dept_1=dept[0:20]
dept_2=dept[20:40]
dept_3=dept[40:60]
dept_4=dept[60:]

#Creating the subplots with 2 rows and 2 columns and adjusting the spacing betweeen the subplots.
fig, ax=plt.subplots(2,2, figsize=(20,10))
fig.subplots_adjust(wspace=0.5, hspace=0.5)
fig.subplots_adjust(left=0.1, right=0.9, bottom=0.1, top=0.9)

#For each batch containg departments and for each department in each batch plot the weekly sales in accordance with date.
for i in dept_1:
    data_1= data[data['Dept']==i]
    ax[0,0].plot(data_1['Date'], data_1['Weekly_Sales'], label='Dept_1_mean_sales')
for i in dept_2:
    data_1=data[data['Dept']==i]
    ax[0,1].plot(data_1['Date'], data_1['Weekly_Sales'], label ='Dept_1_mean_sales')
for i in dept_3:
    data_1=data[data['Dept']==i]
    ax[1,0].plot(data_1['Date'], data_1['Weekly_Sales'], label='Dept_1_mean_sales')
for i in dept_4:
    data_1=data[data['Dept']==i]
    ax[1,1].plot(data_1['Date'], data_1['Weekly_Sales'], label='Dept_1_mean_sales')
    
#Give each subplot a suitable title    
ax[0,0].set_title('Mean sales record by department (0-19)')
ax[0,1].set_title('Mean sales record by department (20-39)')
ax[1,0].set_title('Mean sales record by department (40-59)')
ax[1,1].set_title('Mean sales record by department (60-)')

#Give each Subplot y and x labels
ax[0,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,0].set_xlabel('Date')
ax[0,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[0,1].set_xlabel('Date')
ax[1,0].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,0].set_xlabel('Date')
ax[1,1].set_ylabel('Mean sales With Respect To Specified Departments')
ax[1,1].set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# 1)The sales level is different by department
#
# 2)There is some peaked points around January and May, thus indicating high sales during those times.
#
# We can see that departments and date are good features to predict the sales.
